# %%
#backup

import tkinter as tk
from tkinter import filedialog
from tkinter import *
from PIL import ImageTk, Image
from keras.preprocessing import image
import numpy as np
import h5py
import cv2
import tensorflow as tf
from tensorflow import keras
#load the trained model to classify image
#from keras.models import load_model
model = keras.models.load_model('final-5-class.h5')

    
          
                 
#initialise GUI
top=tk.Tk()
top.geometry('800x600')
top.title('face classification')
top.configure(background='lightblue')

label=Label(top,background='green', font=('arial',15,'bold'))
sign_image = Label(top)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')


def classify(file_path):
    global label_packed
    #imag = Image.open(file_path).convert("RGB")
    #image = face_cascade.detectMultiScale(image)
    #image=image.resize((200,200),Image.ANTIALIAS)
    #image=numpy.array(image.getdata()).reshape(-1,30,30,3)
    #image = image.img_to_array(image)
    #print(image.shape)
    #test_image=np.array(imag.getdata())
    img=cv2.imread(file_path)
    imag = cv2.resize(img,(int(img.shape[1]/2), int(img.shape[0]/2)))
    #imag = cv2.cvtColor(imag,cv2.COLOR_RGB2GRAY) #gray scale conversion
    #imag=cv2.resize(imag,(500,500))
    faces=face_cascade.detectMultiScale(imag)
    if faces==():
        att = "Difficult to detect face"
        label.configure(foreground='white', text=att)
        exit()
    for (x, y, w, h) in faces:
        i = cv2.rectangle(imag, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roi_color = i[y:y+h, x:x+w]
    #test_image = image.load_img(roi_color, target_size = (200,200))
    #if image not found ?
    #print(len(roi_color))
    test_image=cv2.resize(roi_color,(200,200))
    #cv2.imshow("img",test_image)
    #cv2.waitKey()
    test_image = image.img_to_array(test_image)/255.
    test_image = np.expand_dims(test_image, axis=0)
    luna = model.predict_proba(test_image)
    print(luna)
    #pred = model.predict_classes([image])[0]
    #result=model.predict(image)
    #sign = classes[pred+1]
    
#classifier = keras.models.load_model("unknownfacepredict.h5")
#test_image_luna = image.load_img(r'C:\Users\dell\Desktop\saugat\dummy\zebrish\237237_faces.jpg', target_size=(200,200))
#test_image2 = image.img_to_array(test_image_luna)/255.
#test_image2 = np.expand_dims(test_image2, axis=0)
#luna = classifier.predict_proba(test_image2)

#at = np.round(luna*100,2)
#float(luna)[0]
    np.set_printoptions(suppress=True)
    print(max(max(luna)))
    if max(max(luna)) == max(luna)[2]:
        if max(max(luna))>0.80:
            at = "ramesh"
        else:
            at="probably ramesh but not sure"
        
    elif max(max(luna)) == max(luna)[3]:
        if max(max(luna))>0.90:
            at = "saugat"
        else:
            at="probably saugat but not sure"

    elif max(max(luna)) == max(luna)[1]:
        if max(max(luna))>0.80:
            at = "mitra"
        else:
            at="probably mitra but not sure"

    elif max(max(luna)) == max(luna)[0]:
        if max(max(luna))>0.80:
            at = "bishal"
        else:
            at="probably bishal but not sure"
    
         
    elif max(max(luna)) == max(luna)[4]:
        if max(max(luna))>0.90:
            at = "unknown"
        else:
            at="unknown"

    else:
        at="super"
    #print(sign)
    #label.configure(foreground='#011638', text=at) 
    label.configure(foreground='white', text=at)
    
   
def show_classify_button(file_path):
    classify_b=Button(top,text="Classify image",command=lambda: classify(file_path),padx=10,pady=5)
    classify_b.configure(background='blue', foreground='white',font=('arial',10,'bold'))
    classify_b.place(relx=0.79,rely=0.46)

def upload_image():
    try:
        file_path=filedialog.askopenfilename()
        uploaded=Image.open(file_path)
        uploaded.thumbnail(((top.winfo_width()/2.25),(top.winfo_height()/2.25)))
        im=ImageTk.PhotoImage(uploaded)
        
        sign_image.configure(image=im)
        sign_image.image=im
        label.configure(text='')
        show_classify_button(file_path)
    except:
        pass

upload=Button(top,text="Upload",command=upload_image,padx=10,pady=5)
upload.configure(background='red', foreground='white',font=('arial',10,'bold'))

upload.pack(side=BOTTOM,pady=50)
sign_image.pack(side=BOTTOM,expand=True)
label.pack(side=BOTTOM,expand=True)
heading = Label(top, text="classify image",pady=20, font=('arial',20,'bold'))
heading.configure(background='white',foreground='green')
heading.pack()

#names = Label(top, text="""People we exepect to recognize
 #                           1. Deepika padukone
  #                          2. Leonardo dicarpio
   #                         3. Virat kohli""").grid(row=1,colum=1)


top.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dell\Anaconda3\envs\tf_env\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-14-3eb4d9210f8f>", line 115, in <lambda>
#     classify_b=Button(top,text="Classify image",command=lambda: classify(file_path),padx=10,pady=5)
#   File "<ipython-input-14-3eb4d9210f8f>", line 43, in classify
#     imag=cv2.resize(imag,(500,500))
# UnboundLocalError: local variable 'imag' referenced before assignment

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import *
from PIL import ImageTk, Image
from keras.preprocessing import image
import numpy as np
import h5py
from PIL import ExifTags

import cv2
import tensorflow as tf
from tensorflow import keras
#load the trained model to classify image
#from keras.models import load_model
model = keras.models.load_model('final-5-class.h5')

    
          
                 
#initialise GUI
top=tk.Tk()
top.geometry('800x600')
top.title('face classification')
top.configure(background='lightblue')

label=Label(top,background='green', font=('arial',15,'bold'))
sign_image = Label(top)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')


def classify(file_path):
    global label_packed
    #imag = Image.open(file_path).convert("RGB")
    #image = face_cascade.detectMultiScale(image)
    #image=image.resize((200,200),Image.ANTIALIAS)
    #image=numpy.array(image.getdata()).reshape(-1,30,30,3)
    #image = image.img_to_array(image)
    #print(image.shape)
    #test_image=np.array(imag.getdata())
    imag=cv2.imread(file_path)
    imag = cv2.resize(imag,(int(imag.shape[1]/2.5), int(imag.shape[0]/2.5)))
    imag = cv2.GaussianBlur(imag,(5,5),0)
    #imag = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY) #gray scale conversion
    #imag=cv2.resize(imag,(500,500))
    faces=face_cascade.detectMultiScale(imag)
    if faces==():
        att = "Difficult to detect face"
        label.configure(foreground='white', text=att)
        sys.exit()
    for (x, y, w, h) in faces:
        i = cv2.rectangle(imag, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roi_color = i[y:y+h, x:x+w]
    #test_image = image.load_img(roi_color, target_size = (200,200))
    #if image not found ?
    #print(len(roi_color))
    test_image=cv2.resize(roi_color,(200,200))
    cv2.imshow("img",test_image)
    #cv2.waitKey()
    test_image = image.img_to_array(test_image)/255.
    test_image = np.expand_dims(test_image, axis=0)
    luna = model.predict_proba(test_image)
    print(luna)
    #pred = model.predict_classes([image])[0]
    #result=model.predict(image)
    #sign = classes[pred+1]
    
#classifier = keras.models.load_model("unknownfacepredict.h5")
#test_image_luna = image.load_img(r'C:\Users\dell\Desktop\saugat\dummy\zebrish\237237_faces.jpg', target_size=(200,200))
#test_image2 = image.img_to_array(test_image_luna)/255.
#test_image2 = np.expand_dims(test_image2, axis=0)
#luna = classifier.predict_proba(test_image2)

#at = np.round(luna*100,2)
#float(luna)[0]
    np.set_printoptions(suppress=True)
    print(max(max(luna)))
    if max(max(luna)) == max(luna)[2]:
        if max(max(luna))>0.80:
            at = "mitra"
        else:
            at="probably mitra but not sure"
        
    elif max(max(luna)) == max(luna)[3]:
        if max(max(luna))>0.90:
            at = "saugat"
        else:
            at="probably saugat but not sure"

    elif max(max(luna)) == max(luna)[1]:
        if max(max(luna))>0.80:
            at = "ramesh"
        else:
            at="probably ramesh but not sure"

    elif max(max(luna)) == max(luna)[0]:
        if max(max(luna))>0.80:
            at = "bishal"
        else:
            at="probably bishal but not sure"
    
         
    elif max(max(luna)) == max(luna)[4]:
        if max(max(luna))>0.90:
            at = "unknown"
        else:
            at="unknown"

    else:
        at="super"
    #print(sign)
    #label.configure(foreground='#011638', text=at) 
    label.configure(foreground='white', text=at)
    
   
def show_classify_button(file_path):
    classify_b=Button(top,text="Classify image",command=lambda: classify(file_path),padx=10,pady=5)
    classify_b.configure(background='blue', foreground='white',font=('arial',10,'bold'))
    classify_b.place(relx=0.79,rely=0.46)

def upload_image():
    try:
        file_path=filedialog.askopenfilename()
        image=Image.open(file_path)
        for orientation in ExifTags.TAGS.keys() : 
            if ExifTags.TAGS[orientation]=='Orientation' : break 
        exif=dict(image._getexif().items())

        if   exif[orientation] == 3 : 
            image=image.rotate(180, expand=True)
        elif exif[orientation] == 6 : 
            image=image.rotate(270, expand=True)
        elif exif[orientation] == 8 : 
            image=image.rotate(90, expand=True)
        image.thumbnail(((top.winfo_width()/2.25),(top.winfo_height()/2.25)),Image.ANTIALIAS)
        im=ImageTk.PhotoImage(image)
        
        sign_image.configure(image=im)
        sign_image.image=im
        label.configure(text='')
        show_classify_button(file_path)
    except:
        pass

upload=Button(top,text="Upload",command=upload_image,padx=10,pady=5)
upload.configure(background='red', foreground='white',font=('arial',10,'bold'))

upload.pack(side=BOTTOM,pady=50)
sign_image.pack(side=BOTTOM,expand=True)
label.pack(side=BOTTOM,expand=True)
heading = Label(top, text="classify image",pady=20, font=('arial',20,'bold'))
heading.configure(background='white',foreground='green')
heading.pack()

#names = Label(top, text="""People we exepect to recognize
 #                           1. Deepika padukone
  #                          2. Leonardo dicarpio
   #                         3. Virat kohli""").grid(row=1,colum=1)


top.mainloop()
# Out:
# C:\Users\dell\Anaconda3\envs\tf_env\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# [[0.00000096 0.00002975 0.00005688 0.9999124  0.00000001]]
# 0.9999124
# [[0.00000159 0.00003568 0.00000955 0.99995315 0.        ]]
# 0.99995315
# [[0.00000169 0.00005533 0.00010231 0.9998406  0.00000002]]
# 0.9998406
